# %% [markdown]
# # 🐍 Explorando o Poder do Python
#
# Este notebook mostra várias coisas legais que você pode fazer com Python!

# %% [markdown]
# ## 1. Básico: Variáveis e Operações

# %%
a = 10
b = 5

print("Soma:", a + b)
print("Multiplicação:", a * b)

# %% [markdown]
# ## 2. Listas e Loops

# %%
numeros = [1, 2, 3, 4, 5]

for n in numeros:
    print(n**2)

# %% [markdown]
# ## 3. Funções

# %%
def saudacao(nome):
    return f"Olá, {nome}!"

print(saudacao("Mundo"))

# %% [markdown]
# ## 4. Trabalhando com Arquivos

# %%
with open("exemplo.txt", "w") as f:
    f.write("Python é incrível!")

with open("exemplo.txt", "r") as f:
    print(f.read())

# %% [markdown]
# ## 5. Visualização de Dados

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)
plt.title("Gráfico simples")
plt.show()

# %% [markdown]
# ## 6. Mini Projeto: Jogo de Adivinhação

# %%
import random

numero = random.randint(1, 10)
palpite = int(input("Adivinhe um número de 1 a 10: "))

if palpite == numero:
    print("Acertou!")
else:
    print("Errou! O número era", numero)

# %% [markdown]
# ## 7. Automação Simples

# %%
import os

arquivos = os.listdir()
print("Arquivos na pasta:")
for a in arquivos:
    print(a)

# %% [markdown]
# ## 8. Trabalhando com APIs

# %%
import requests

resposta = requests.get("https://api.github.com")
print(resposta.status_code)

# %% [markdown]
# ## 9. Inteligência Artificial (simples exemplo)

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

x = np.array([[1], [2], [3], [4]])
y = np.array([2, 4, 6, 8])

modelo = LinearRegression()
modelo.fit(x, y)

print("Previsão para 5:", modelo.predict([[5]]))
